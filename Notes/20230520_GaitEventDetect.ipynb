# %%
import os
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
path = "/Users/wangshuaibo/Documents/北京悦动/脑卒中项目/阿帅笔记/HarbinStroke/Xsens/Process_Data/Excel"

# %%
os.chdir(path)

# %%
os.listdir(path)
# Out:
# ['20230519_方克彦_Xsens_穿鞋-2.xlsx',
#  '20230519_安俊宇_Xsens_穿鞋-1.xlsx',
#  '20230519_方克彦_Xsens_赤足-2.xlsx',
#  '20230519_方克彦_Xsens_赤足-3.xlsx',
#  '20230519_方克彦_Xsens_穿鞋-3.xlsx',
#  '20230519_安俊宇_Xsens_穿鞋-3.xlsx',
#  '20230519_方克彦_Xsens_赤足-1.xlsx',
#  '20230519_方克彦_Xsens_穿鞋-1.xlsx',
#  '20230519_安俊宇_Xsens_穿鞋-2.xlsx']

# %%
file_list = os.listdir(path)
filename = file_list[0]
excelfile = pd.ExcelFile(filename,engine='openpyxl')
sheet_name = excelfile.sheet_names
print(f"sheetname is:\n {sheet_name}")
# Out:
# sheetname is:
#  ['General Information', 'Markers', 'Segment Orientation - Quat', 'Segment Orientation - Euler', 'Segment Position', 'Segment Velocity', 'Segment Acceleration', 'Segment Angular Velocity', 'Segment Angular Acceleration', 'Joint Angles ZXY', 'Joint Angles XZY', 'Ergonomic Joint Angles ZXY', 'Ergonomic Joint Angles XZY', 'Center of Mass', 'Sensor Free Acceleration', 'Sensor Magnetic Field', 'Sensor Orientation - Quat', 'Sensor Orientation - Euler']

# %%
df = pd.read_excel(filename, sheet_name="Segment Position")

# %%
df["Left Foot z"].loc[1000:1500].plot()
# Out:
# <Axes: >

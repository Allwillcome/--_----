# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = "/Users/wangshuaibo/Documents/ScriptsofShuai/gaitpy_exercise/"
os.chdir(path)

# %%
xsens_file = "20230413跺脚走6步路测试-XsensMVN-传感器加速度.xlsx"
df = pd.read_excel(xsens_file,engine="openpyxl")
df.head(3)
# Out:
#                 timestamps  Pelvis x  Pelvis y  Pelvis z  L5 x  L5 y  L5 z  \
# 0  2023-04-15 12:00:00:000 -0.008742  0.019561 -0.011491     0     0     0
# 1  2023-04-15 12:00:00:001  0.016164  0.015704  0.011848     0     0     0
# 2  2023-04-15 12:00:00:002 -0.014526  0.054576 -0.023304     0     0     0
#
#    L3 x  L3 y  L3 z  ...  Left Upper Leg z  Left Lower Leg x  \
# 0     0     0     0  ...         -0.013239         -0.005245
# 1     0     0     0  ...         -0.013241          0.045763
# 2     0     0     0  ...         -0.031757          0.002115
#
#    Left Lower Leg y  Left Lower Leg z  Left Foot x  Left Foot y  Left Foot z  \
# 0          0.010545         -0.000286     0.014797    -0.006973     0.026653
# 1         -0.000241         -0.017675     0.034946     0.004807     0.019792
# 2          0.029728         -0.028391     0.001224     0.007672     0.012579
#
#    Left Toe x  Left Toe y  Left Toe z
# 0           0           0           0
# 1           0           0           0
# 2           0           0           0
#
# [3 rows x 70 columns]

# %%
"""
from datetime import datetime, timedelta

start_time = datetime(2023, 4, 15, 12, 0, 0, 0)  # 开始时间
time_step = timedelta(milliseconds=1)  # 时间步长为 1 毫秒
# 生成 2423 个时间戳
time_series = [start_time + i*time_step for i in range(2423)]
time_series_str = [t.strftime('%Y-%m-%d %H:%M:%S:%f')[:-3] for t in time_series]
df["timestamps"] = pd.DataFrame(time_series_str)


df.head(3)
"""
# Out:
#    Frame  Pelvis x  Pelvis y  Pelvis z  L5 x  L5 y  L5 z  L3 x  L3 y  L3 z  \
# 0      0 -0.008742  0.019561 -0.011491     0     0     0     0     0     0
# 1      1  0.016164  0.015704  0.011848     0     0     0     0     0     0
# 2      2 -0.014526  0.054576 -0.023304     0     0     0     0     0     0
#
#    ...  Left Lower Leg x  Left Lower Leg y  Left Lower Leg z  Left Foot x  \
# 0  ...         -0.005245          0.010545         -0.000286     0.014797
# 1  ...          0.045763         -0.000241         -0.017675     0.034946
# 2  ...          0.002115          0.029728         -0.028391     0.001224
#
#    Left Foot y  Left Foot z  Left Toe x  Left Toe y  Left Toe z  \
# 0    -0.006973     0.026653           0           0           0
# 1     0.004807     0.019792           0           0           0
# 2     0.007672     0.012579           0           0           0
#
#                 timestamps
# 0  2023-04-15 12:00:00:000
# 1  2023-04-15 12:00:00:001
# 2  2023-04-15 12:00:00:002
#
# [3 rows x 71 columns]

# %%
df["timestamps"] = pd.to_datetime(df["timestamps"], format="%Y-%m-%d %H:%M:%S:%f")

df["timestamps"].astype('datetime64[ms]')
# Out:
# 0      2023-04-15 12:00:00.000
# 1      2023-04-15 12:00:00.001
# 2      2023-04-15 12:00:00.002
# 3      2023-04-15 12:00:00.003
# 4      2023-04-15 12:00:00.004
#                  ...
# 2418   2023-04-15 12:00:02.418
# 2419   2023-04-15 12:00:02.419
# 2420   2023-04-15 12:00:02.420
# 2421   2023-04-15 12:00:02.421
# 2422   2023-04-15 12:00:02.422
# Name: timestamps, Length: 2423, dtype: datetime64[ns]

# %%
df =

# %% [markdown]
# import gait.util as ytil

# %%
from gaitpy.gait import Gaitpy

raw_data = "demo_data_modified.csv"
sample_rate = 50 # hertz
subject_height = 177 # centimeters

#### Create an instance of Gaitpy ####
gaitpy = Gaitpy(raw_data,                           # Raw data consisting of vertical acceleration from lumbar location and unix timestamps
                sample_rate,                        # Sample rate of raw data (in Hertz)
                v_acc_col_name='y',                 # Vertical acceleration column name
                ts_col_name='timestamps',           # Timestamp column name
                v_acc_units='m/s^2',                # Units of vertical acceleration
                ts_units='ms',                      # Units of timestamps
                flip=False)                         # If baseline data is at +1g or +9.8m/s^2, set flip=True

                                  # Specify whether to display plot upon completion (True by default)

# %%
from gaitpy.gait import Gaitpy

raw_data = df
sample_rate = 100 # hertz
subject_height = 170 # centimeters

#### Create an instance of Gaitpy ####
gaitpy = Gaitpy(raw_data,                           # Raw data consisting of vertical acceleration from lumbar location and unix timestamps
                sample_rate,                        # Sample rate of raw data (in Hertz)
                v_acc_col_name='Pelvis y',                 # Vertical acceleration column name
                ts_col_name='timestamps',           # Timestamp column name
                v_acc_units='m/s^2',                # Units of vertical acceleration
                ts_units='ms',                      # Units of timestamps
                flip=False)                         # If baseline data is at +1g or +9.8m/s^2, set flip=True

                                  # Specify whether to display plot upon completion (True by default)

# %%
#### Classify bouts of gait - Optional (use if your data consists of gait and non-gait periods)####
# gait_bouts = gaitpy.classify_bouts(result_file='/my/folder/classified_gait.h5')     # File to save results to (None by default)

#### Extract gait characteristics ####
gait_features = gaitpy.extract_features(subject_height,                               # Subject height
                                        subject_height_units='centimeter',            # Units of subject height
                                        result_file='gait_features.csv',   # File to save results to (None by default)
                                        classified_gait=None)                   # Pandas Dataframe or .h5 file results of classify_bouts function (None by default)
# Out:
# 	Extracting features...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/GaitPy/lib/python3.6/site-packages/pandas/core/frame.py in _ensure_valid_index(self, value)
#    3169             try:
# -> 3170                 value = Series(value)
#    3171             except (ValueError, NotImplementedError, TypeError) as err:
#
# ~/anaconda3/envs/GaitPy/lib/python3.6/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     230
# --> 231             if is_empty_data(data) and dtype is None:
#     232                 # gh-17261
#
# ~/anaconda3/envs/GaitPy/lib/python3.6/site-packages/pandas/core/construction.py in is_empty_data(data)
#     595     is_list_like_without_dtype = is_list_like(data) and not hasattr(data, "dtype")
# --> 596     is_simple_empty = is_list_like_without_dtype and not data
#     597     return is_none or is_simple_empty
#
# ~/anaconda3/envs/GaitPy/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1329         raise ValueError(
# -> 1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-5782bd6e70a7> in <module>
#       6                                         subject_height_units='centimeter',            # Units of subject height
#       7                                         result_file='gait_features.csv',   # File to save results to (None by default)
# ----> 8                                         classified_gait=None)                   # Pandas Dataframe or .h5 file results of classify_bouts function (None by default)
#
# ~/anaconda3/envs/GaitPy/lib/python3.6/site-packages/gaitpy-1.6.1-py3.6.egg/gaitpy/gait.py in extract_features(self, subject_height, subject_height_units, sensor_height_ratio, result_file, classified_gait, ic_prom, fc_prom)
#     136             bout_indices = (timestamps.astype('datetime64[ms]') >= bout.start_time) & (timestamps.astype('datetime64[ms]') <= bout.end_time)
#     137             bout_data = pd.DataFrame([])
# --> 138             bout_data['y'] = pd.DataFrame(y_accel.loc[bout_indices].reset_index(drop=True))
#     139             bout_data['ts'] = timestamps.loc[bout_indices].reset_index(drop=True)
#     140             if len(bout_data.y) <= 15:
#
# ~/anaconda3/envs/GaitPy/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3042         else:
#    3043             # set column
# -> 3044             self._set_item(key, value)
#    3045
#    3046     def _setitem_slice(self, key: slice, value):
#
# ~/anaconda3/envs/GaitPy/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3117         ensure homogeneity.
#    3118         """
# -> 3119         self._ensure_valid_index(value)
#    3120         value = self._sanitize_column(key, value)
#    3121         NDFrame._set_item(self, key, value)
#
# ~/anaconda3/envs/GaitPy/lib/python3.6/site-packages/pandas/core/frame.py in _ensure_valid_index(self, value)
#    3173                     "Cannot set a frame with no defined index "
#    3174                     "and a value that cannot be converted to a Series"
# -> 3175                 ) from err
#    3176
#    3177             # GH31368 preserve name of index
#
# ValueError: Cannot set a frame with no defined index and a value that cannot be converted to a Series

# %%
#### Plot results of gait feature extraction ####
gaitpy.plot_contacts(gait_features,                                     # Pandas Dataframe or .csv file results of extract_features function
                     result_file='plot_contacts.html)',      # File to save results to (None by default)
                     show_plot=True)

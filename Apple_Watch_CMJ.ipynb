# %%
import os
import pandas as pd
import numpy as np
from scipy.signal import find_peaks
import matplotlib.pyplot as plt

# %%
# %matplotlib ipympl

# %%
f_path = '/Users/wangshuaibo/Downloads/12_31_08-34-07_wangshuaibo_conutmovement_jump_1_times'
os.chdir(f_path)
os.listdir()
f_name = "GravityAndAttitude.csv"
path_name = os.path.join(f_path, f_name)

# %%
df = pd.read_csv(path_name)

# %%
df.iloc[:,1:7].plot()
# Out:
# <AxesSubplot: >
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()
df[" gravityX"].plot()
# Out:
# <AxesSubplot: >
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
axis = df.columns[1:7].tolist()
type(axis)
eff_axis = axis[0]
eff_axis_data = df[eff_axis]

# %%
#查找峰值
peaks, properties = find_peaks(eff_axis_data, prominence=(0.1,0.3))

plt.close()
plt.plot(eff_axis_data)
plt.plot(peaks, eff_axis_data[peaks], "x" )
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
peaks
# Out:
# array([537, 613])

# %%
t = (600-537)/100
print(t)
h
# Out:
# 0.63
# 0.4862025000000001

# %%
# 使用腾空时间计算纵跳高度
h = 1/2 * 9.8 * np.square(t/2)
#输出腾空时间
print("腾空高度为 {} 厘米".format(int(h*100)))
# Out:
# 腾空高度为 48 厘米
